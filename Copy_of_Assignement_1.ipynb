# %% [markdown]
# <a href="https://colab.research.google.com/github/mariianagonzalezv-gif/Assignment-1/blob/main/Copy_of_Assignement_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CISC 121 – Assignment-1
#
# ## 🔗 Problem
# Fizz Buzz – https://leetcode.com/problems/fizz-buzz/
#
# Palindrome Number – https://leetcode.com/problems/palindrome-number/
#
# Reverse Integer – https://leetcode.com/problems/reverse-integer/
#
# Two Sum – https://leetcode.com/problems/two-sum/
#
# Valid Palindrome – https://leetcode.com/problems/valid-palindrome/

# %% [markdown]
# #  Problem 1

# %% [markdown]
# ## 1. Understanding & Breakdown
#
# ![fizzbuzz.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 2. Peer Review & Draft Code
# I reviewed one of the top solutions on the "Solutions" tab on LeetCode:https://leetcode.com/problems/fizz-buzz/solutions/4345360/beats-100-3-approaches-full-explained-java-c-python-javascript/
#
# With this, I learned that I must define the "n" using a simple definition, as well as setting the answer equal to two square brackets, so I can later return it to print the final answer. Using this, I will try to write a function that involves what I learned as well as what I had previously planned that accurately gives the correct output.

# %%
# Your draft code here (does not need to be fully correct)

#define variable n and answer
def fizzbuzz(n):
  answer = []

#must make the end rage n+1 because python ends one before the end number
  for i in range(1, n+1):
    #if the integer is divisible by 3, and 5 return FizzBuzz
    if i % 3 == 0 and i % 5 == 0:
      answer.append("FizzBuzz")
    #if integer only divisible by 3, return Fizz
    elif i % 3 == 0:
      answer.append("Fizz")

    #if integer only divisble by 5, return Buzz
    elif i % 5 == 0:
      answer.append("Buzz")
    #if none of the above, return the number itself
    else:
      answer.append(str(i))

  return answer

# %% [markdown]
# ## 3. Final Correct Code
#
# After the first test case this is the error that came back:
# ![testcase 1.PNG](data:image/png;base64,...)
# So I used Chat-GPT to help me understand what was wrong with my code. I used the prompt "help me understand how to fix the indentation problem with this code". It helped me understand that the indentation I used when on LeetCode wasn't correct, and helped me correct the error I had made.
#
# After fixing my error, I ran the code again and all three of the test cases were accepted
# ![testcase 1.0.PNG](data:image/png;base64,...)
# ![test case 2.PNG](data:image/png;base64,...)
# ![test case 3.PNG](data:image/png;base64,...)

# %%
# Final working solution
# AI Disclaimer: I used Chat-GPT to help me understand where my indentation issues came from using the prompt: "help me understand how to fix the indentation problem with this code"

class Solution:
    def fizzBuzz(self, n: int) -> List[str]:
        answer = []   # create an empty list

        # must make the end range n+1 because Python's range stops one before the end number
        for i in range(1, n+1):
            if i % 3 == 0 and i % 5 == 0:
                answer.append("FizzBuzz")

            elif i % 3 == 0:
                answer.append("Fizz")

            elif i % 5 == 0:
                answer.append("Buzz")

            else:
                answer.append(str(i))

        return answer

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
# Fix 1: fixed the indentation issues that would not let the code run overall:

class Solution:
    def fizzBuzz(self, n: int) -> List[str]:
        answer = []   # create an empty list

        # must make the end range n+1 because Python's range stops one before the end number
        for i in range(1, n+1):
            if i % 3 == 0 and i % 5 == 0:
                answer.append("FizzBuzz")

            elif i % 3 == 0:
                answer.append("Fizz")

            elif i % 5 == 0:
                answer.append("Buzz")

            else:
                answer.append(str(i))

        return answer

# %%
# Fix 2: changed the definition to the one provided on LeetCode to allow the code to run properly on there

# Draft version:
def fizzbuzz(n):

# Fixed version:
def fizzBuzz(self, n: int) -> List[str]:

# %% [markdown]
# ## 5. Reflection on Your Contribution
# _Where did AI or Other's code helped or fail to help? What specific logic or debugging did you contribute yourself?_
#
# ## Example
# 1. I used ChatGPT to help identify specific syntax and indentation errors in my intial code. For example, it pointed out that the indentation was off in my code, and solely because of that it was not running
#
# 2.  I used ChatGPT (Level 1) to help understand the overall problem and explain any unknown terms.
#
# 3. I used code from the "Solutions" section on LeetCode to help fill in any holes in my knowledge. It taught me to use certain functions that I wasn't necessarily thinking of using in the first place

# %% [markdown]
# #  Problem 2

# %% [markdown]
# ## 1. Understanding & Breakdown
#
# ![palindrome number.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 2. Peer Review & Draft Code
# I reviewed one of the top solutions under the LeetCode "Solutions" tab: https://leetcode.com/problems/palindrome-number/solutions/5980505/step-by-steps-solution-best-method-beats-100-user-beginner-friendly/
# Instead of converting it to a string and using the slicing function, I can use basic modulo operation (%), multiplication (*), and floor division (//) to reverse the inputted number.

# %%
# Your draft code here (does not need to be fully correct)
class Solution:
    def isPalindrome(self, x: int) -> bool:

      #define x as the original number sequence
        x = original

        #if x is negative, automatically return false (CANNOT BE PALINDROME)
        if x < 0:
          return False

        #set reversed number as0
        reversed_num = 0

        #if the integer is greater than 0 (which it has to be to be a palindrome),do the following:
        if x > 0:
          #this isolates the last digit as it would be the remainder when the integer gets divided by 10
          last_digit = original % 10

          #shift digits left (multiply by 10) and add the new last digit
          reversed_num = reversed_num * 10 + last_digit
          #removes the last digit from original (integer division by 10)
          original = original//10
          original == reversed_num
          #returns true if original is equal to the reversed!
          return True

# %% [markdown]
# ## 3. Final Correct Code
# I ran my original code, and the first two test cases ran, but the third one failed as it returned "true" instead of false". After that, I readover my code, and saw that I needed to add an additional statement to the first conditional if in order for it to run properly. After running it again, all three test cases ran properly and were approved.
#
# ![test case 2.1.PNG](data:image/png;base64,...)
# ![test case 2.2.PNG](data:image/png;base64,...)
# ![test case 2.3.PNG](data:image/png;base64,...)

# %%
# Final working solution
# AI Disclaimer: No AI was used to fix this code.
class Solution:
    def isPalindrome(self, x: int) -> bool:
      # define x as the original number sequence
        original = x

        # if x is negative OR ends with 0 (but isn’t 0),
        # it cannot be a palindrome, so automatically return false
        if x < 0 or x % 10 == 0:
            return False

        # set reversed number as 0
        reversed_num = 0

         # if the integer is greater than 0 (needed to check for palindrome), do the following:
        while x > 0:

          # this isolates the last digit (remainder when dividing by 10)
            last_digit = original % 10

            # shift digits left (multiply by 10) and add the new last digit
            reversed_num = reversed_num * 10 + last_digit

            original = original//10

            #if original is equal to reversed, return true!
            return original == reversed_num

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
# Fix 1: fixed the order when creating the copy of the variable x named original, as the original version was incorrect and would not let the code run

# Draft version:
x = original

# Fixed version:
original = x

# %%
# Fix 2: added an additonal condition that would need to be met, as without it a number like 10 would come back as "true", even though it is not a palindrome

# Draft version:
if x < 0:
  return False

# Fixed version:
if x < 0 or x % 10 == 0:
  return False

# %% [markdown]
# ## 5. Reflection on Your Contribution
# _Where did AI or Other's code helped or fail to help? What specific logic or debugging did you contribute yourself?_
#
# 1. The solution I found on LeetCode is what helped me to solve this problem the most, as going into this, I had a completely different approach in mind. It helped me realise that I can use basic callbacks such as modulo operation (%), multiplication (*), and floor division (//), instead of a more complicated approach with strings and loops.
# 2. I did not use AI to fix my code as when I first ran the code, the first two test cases worked, but the third one (which was x=10) did not pass (returned "True" instead of "False". I carefully reread my code and compared the approved test cases to the one that failed, and that helped me realise that I had to add an extra condition in order for multiples of 10 to come back false instead of true.

# %% [markdown]
# #  Problem 3

# %% [markdown]
# ## 1. Understanding & Breakdown
#
# ![reverse integer.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 2. Peer Review & Draft Code
# I reviewed one of the top solutions under the LeetCode "Solutions" tab: https://leetcode.com/problems/reverse-integer/solutions/5428589/video-using-remainder
#
# With this solution I confirmed that my original idea of following similar steps as in the "Palindrome Number" problem would work. However, I learned that for this specific problem I have to make any negative input positive in order for the function to work a bit easier (and then later on when returning the reversed number, make it negative again). Lastly, I learned to use while, instead of if

# %%
# Your draft code here (does not need to be fully correct)
class Solution:
  def reverse(self, x: int) -> int:
      # define x as the original number sequence
    original = x

        # if x is negative, make it positive for now (handle sign later)
    if x < 0:
        x *= -1
    # set reversed number as 0
    reversed_num = 0


        # while x still has digits, keep reversing
    while x > 0:

          # isolate the last digit (remainder when dividing by 10)
      last_digit = original % 10

            # shift digits left (multiply by 10) and add the new last digit
      reversed_num = reversed_num * 10 + last_digit

            # remove the last digit from x (integer division by 10)
      x = x//10

        # if reversed number goes past 32-bit integer max, return 0
    if reversed_num > 2 ** 31 -1 :
      return 0

        # return the reversed number
    return reversed_num

# %% [markdown]
# ## 3. Final Correct Code
# ![test case 3.3.PNG](data:image/png;base64,...)![test case 3.2.PNG](data:image/png;base64,...)![test case 3.1.PNG](data:image/png;base64,...)

# %%
#AI Disclaimer: Asked Chat-GPT for help using the prompt "can you explain why my code went wrong only when its a negative number."
class Solution:
  def reverse(self, x: int) -> int:
        # define x as the original number sequence
    original = x

        # flag for negative numbers
    is_negative = False
    if x < 0:
      is_negative = True
      x *= -1  # make x positive to simplify reversing

        # set reversed number as 0
    reversed_num = 0

        # while x still has digits, keep reversing
    while x > 0:
            # isolate the last digit (remainder when dividing by 10)
      last_digit = x % 10

            # shift digits left (multiply by 10) and add the new last digit
      reversed_num = reversed_num * 10 + last_digit

            # remove the last digit from x (integer division by 10)
      x = x // 10

        # if original number was negative, put the negative sign back
    if is_negative:
      reversed_num *= -1

        # if reversed number goes outside 32-bit integer range, return 0
    if reversed_num < -2 ** 31 or reversed_num > 2 ** 31 - 1:
      return 0

        # return the reversed number
    return reversed_num

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
# Fix 1: added a negative number "flag". when it is false, nothing changed, but when true it made sure to add back the negative sign to the number.
#draft version: did not have it
class Solution:
  def reverse(self, x: int) -> int:
      # define x as the original number sequence
    original = x

        # if x is negative, make it positive for now (handle sign later)
    if x < 0:
        x *= -1
    # set reversed number as 0
    reversed_num = 0


        # while x still has digits, keep reversing
    while x > 0:

          # isolate the last digit (remainder when dividing by 10)
      last_digit = original % 10

            # shift digits left (multiply by 10) and add the new last digit
      reversed_num = reversed_num * 10 + last_digit

            # remove the last digit from x (integer division by 10)
      x = x//10

        # if reversed number goes past 32-bit integer max, return 0
    if reversed_num > 2 ** 31 -1 :
      return 0

        # return the reversed number
    return reversed_num

#fixed version: added!
class Solution:
  def reverse(self, x: int) -> int:
        # define x as the original number sequence
    original = x

        # flag for negative numbers
    is_negative = False
    if x < 0:
      is_negative = True
      x *= -1  # make x positive to simplify reversing

        # set reversed number as 0
    reversed_num = 0

        # while x still has digits, keep reversing
    while x > 0:
            # isolate the last digit (remainder when dividing by 10)
      last_digit = x % 10

            # shift digits left (multiply by 10) and add the new last digit
      reversed_num = reversed_num * 10 + last_digit

            # remove the last digit from x (integer division by 10)
      x = x // 10

        # if original number was negative, put the negative sign back
    if is_negative:
      reversed_num *= -1

        # if reversed number goes outside 32-bit integer range, return 0
    if reversed_num < -2 ** 31 or reversed_num > 2 ** 31 - 1:
      return 0

        # return the reversed number
    return reversed_num

# %%
# Fix 2: changed the constraint. in the draft version, I only had it capped at 2**31, but in the fixed version, I added the negative constraint as well.
# Draft version:
if reversed_num > 2 ** 31 -1 :
  return 0

# Fixed version:
if reversed_num < -2 ** 31 or reversed_num > 2 ** 31 - 1:
  return 0

# %% [markdown]
# ## 5. Reflection on Your Contribution
# _Where did AI or Other's code helped or fail to help? What specific logic or debugging did you contribute yourself?_
#
# 1. I used Chat-GPT to help me understand why my code was failing on the specific test case that had a negative number. It helped me understand that I had to add a negative number flag and initially set it to false. Then under the if statement where it said if the integer is negative, set it to true. Later on once all the calculations were done, if the negative flag was true, a negative sign was to be added again to the number by multiplying it by -1.
#
# 2. Additionally, I used the solutions tab on LeetCode to confirm my main plan, which was to use a similar code structure to the Palindrome number. (for that I just used my own personal code from Problem 2).

# %% [markdown]
# #  Problem 4

# %% [markdown]
# ## 1. Understanding & Breakdown
#
# ![two sum.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 2. Peer Review & Draft Code
# I reviewed one of the top solutions under the LeetCode "Solutions" tab: https://leetcode.com/problems/two-sum/solutions/3619262/3-method-s-c-java-python-beginner-friendly/
# This solution showed me that I can use the function len to then tell the loop how many times to run (makes sure every number is read). Additionally I learned that I need to create a number map so that each number's index is remembered

# %%
# Your draft code here (does not need to be fully correct)
class Solution:
  def twoSum(self, nums: List[int], target: int) -> List[int]:
    # make a dictionary to keep track of numbers we’ve seen so far
    numberMap = {}

    # loop through the array using the length of nums
    for i in range len(nums):

      # find the other number we need by subtracting current number from target
      number_two = target - nums

      # if the number we need is already in the map, we found a pair
      if number_two in numberMap:
        return [i, numberMap[nums[i]]]

      # otherwise add the current number and its index into the map
      numberMap[nums[i]] = i

    # if nothing is found, just return an empty list
    return []
# Out:
#   File "/tmp/ipython-input-2319263940.py", line 8
#     for i in range len(nums):
#                    ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 3. Final Correct Code
# ![test case 4.3.PNG](data:image/png;base64,...)![test case 4.2.PNG](data:image/png;base64,...)
# ![test case 4.1.PNG](data:image/png;base64,...)

# %%
# Final working solution
# AI Disclaimer: Chat-GPT was used with the following prompts: "what is wrong with my syntax when using len?"
# "explain why i am getting an error saying 'unsupported operand type(s) for -: 'int' and 'list' on line 10"
#"what is wrong with my return on line 14 of my code?"
class Solution:
  def twoSum(self, nums: List[int], target: int) -> List[int]:
    # make a dictionary to keep track of numbers we’ve seen so far
    numberMap = {}

    # loop through the array using the length of nums
    for i in range (len(nums)):

      # find the other number we need by subtracting current number from target
      number_two = target - nums[i]

      # if the number we need is already in the map, we found a pair
      if number_two in numberMap:
        return [numberMap[number_two], i]

      # otherwise add the current number and its index into the map
      numberMap[nums[i]] = i

    # if nothing is found, just return an empty list
    return []

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
# Fix 1: Fixed the error in my loop, as I did not add brackets where needed:

# Draft version:
for i in range len(nums):

# Fixed version:
for i in range (len(nums)):

# %%
# Fix 2: return the stored number first, then current index so the pair is correct
# Draft version:
return [i, numberMap[nums[i]]]

# Fixed version:
return [numberMap[number_two], i]

# %% [markdown]
# ## 5. Reflection on Your Contribution
# _Where did AI or Other's code helped or fail to help? What specific logic or debugging did you contribute yourself?_
#
# 1. I used Chat-GPT to help me understand why my code wasn't working correctly in my first draft. It helped me see that I was using the wrong variable names, like subtracting nums instead of nums[i] and also returning the wrong index from the number map.
#
# 2. Like the previous examples, I also used the solutions tab on LeetCode, and on there I was inspired to used some functions I didn't intitally think of using.

# %% [markdown]
# #  Problem 5

# %% [markdown]
# ## 1. Understanding & Breakdown
#
# ![valid palindrome.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 2. Peer Review & Draft Code
# I reviewed one of the top solutions on LeetCode: https://leetcode.com/problems/valid-palindrome/solutions/7195103/easy-beginner-friendly-solution/
#
# I learned that I can build a new cleaned string by looping through the original string and only keeping the letters and number (exclude spaces, punctuation etc).

# %%
# Your draft code here (does not need to be fully correct)
class Solution:
  def isPalindrome(self, s: str) -> bool:
      #makes all letters lowercase
    reverse = s.lower
      #loops through each character in the string
    for i in s

      #this checks if the character is alpha or numeric
      if i.isalpha() or i.isnumeric():

          #if it is it adds the character to the reverse string
        reverse += i
      #this checks if the string is the same forwards and in reverse, and returns true if it is
    if reverse == reverse(len(output):0:-1):
      return True

      #if it is not it returns false
    else:
      return False

# %% [markdown]
# ## 3. Final Correct Code
#
# > Add blockquote![test case 5.2.PNG](data:image/png;base64,...)![test case 5.1.PNG](data:image/png;base64,...)
# ![test case 5,3.PNG](data:image/png;base64,...)

# %%
# Final working solution
# AI Disclaimer: used Chat-GPT with the following prompts:
#"what is wrong with my syntax in line 14 of this code?"
#"can you explain what this error means, why i got it so i can fix it: unsupported operand type(s) for +=: 'builtin_function_or_method' and 'str' reverse += i "
#"can you explain why i got this error? [image of test case 1: wrong answer]"
class Solution:
  def isPalindrome(self, s: str) -> bool:
      #clean slate
    clean = ""
      #loops through each character in the string
    for i in s :

      #this checks if the character is alpha or numeric
      if i.isalpha() or i.isnumeric():

          #if it is it adds the character to the reverse string
        clean += i.lower()
      #this checks if the string is the same forwards and in reverse, and returns true if it is
    if clean == clean[::-1]:
      return True

      #if it is not it returns false
    else:
      return False

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
# Fix 1: fixed the invalid slicing I tried to do in order to reverse, also changed the name from reverse to clean because it was not really accurate naming

# Draft version:
if reverse == reverse(len(output):0:-1):

# Fixed version:
if clean == clean[::-1]:

# %%
# Fix 2: i corrected the lower() usage and used proper string building

# Draft version:
reverse = s.lower

for i in s
  if i.isalpha() or i.isnumeric():
    reverse += i

# Fixed version:
clean = ""

for i in s :
  if i.isalpha() or i.isnumeric():
    clean += i.lower()

# %% [markdown]
# ## 5. Reflection on Your Contribution
# _Where did AI or Other's code helped or fail to help? What specific logic or debugging did you contribute yourself?_
#
# 1. I used Chat-GPT to help me understand why my first draft of this problem wasn't working correctly. It helped me see that I was making several mistakes like using s.lower without the paranthesis it needed and using invalid slicing methods. It explained how I could make changes, and with that help I was able to do the rest myself.
#
# 2. I made the first draft all by myself, as well as correcting any comments along the way. Another thing I did myself was change the name of the cleaned-out string from reversed to clean, because I hadn't completely thought it out until after.
#
# 3. Lastly, like always the code from LeetCode helped me have a base to build off of, without leeching off of it. Rather I used to better my understanding of the problem and possible functions I could use to complete the task.
